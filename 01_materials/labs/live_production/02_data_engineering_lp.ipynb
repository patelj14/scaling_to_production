# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# PEAK: No timezone found, symbol may be delisted
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 1.840806245803833 seconds.
# Csv file size 14.150974999999999 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 0.37008190155029297 seconds.
# Parquet file size 5.552725 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\nares\AppData\Local\Temp\ipykernel_21220\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.995839   35.126735   34.760220
# A      2013-12-03 00:00:00-05:00   34.635866   34.799492   34.400247
# A      2013-12-04 00:00:00-05:00   34.583499   35.231451   34.504962
# A      2013-12-05 00:00:00-05:00   34.917291   35.211813   34.766757
# A      2013-12-06 00:00:00-05:00   35.185629   35.951385   35.185629
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  128.551783  129.027053  127.274475
# YUM    2024-01-26 00:00:00-05:00  128.640891  129.403315  127.403198
# YUM    2024-01-29 00:00:00-05:00  127.828973  129.264694  127.026935
# YUM    2024-01-30 00:00:00-05:00  129.076565  129.928098  128.304245
# YUM    2024-01-31 00:00:00-05:00  130.155828  130.680609  127.987387
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.825668  2039962        0.0           0.0  2013          NaN
# A        34.642410  3462706        0.0           0.0  2013    34.825668
# A        35.067825  3377288        0.0           0.0  2013    34.642410
# A        35.015465  2530939        0.0           0.0  2013    35.067825
# A        35.885937  4268513        0.0           0.0  2013    35.015465
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.937943  1871700        0.0           0.0  2024   128.165619
# YUM     127.819061  1157000        0.0           0.0  2024   128.937943
# YUM     129.264694  1482100        0.0           0.0  2024   127.819061
# YUM     129.334000  1421500        0.0           0.0  2024   129.264694
# YUM     128.215134  2154200        0.0           0.0  2024   129.334000
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-06-29 23:13:19,957, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-29 23:13:19,957, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-29 23:13:19,961, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-29 23:13:19,961, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-29 23:13:19,973, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-29 23:13:19,973, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-29 23:13:19,976, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-29 23:13:19,976, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-29 23:13:19,979, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:19,979, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:20,117, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-29 23:13:20,117, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-29 23:13:21,333, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-29 23:13:21,333, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-29 23:13:21,333, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:21,333, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:21,549, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-29 23:13:21,549, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-29 23:13:22,631, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-29 23:13:22,631, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-29 23:13:22,632, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:22,632, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:22,728, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-29 23:13:22,728, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-29 23:13:23,901, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-29 23:13:23,901, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-29 23:13:23,917, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:23,917, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:23,987, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-29 23:13:23,987, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-29 23:13:24,599, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-29 23:13:24,599, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-29 23:13:24,599, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:24,599, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:24,679, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-06-29 23:13:24,679, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-06-29 23:13:25,767, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-06-29 23:13:25,767, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-06-29 23:13:25,777, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:25,777, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:26,095, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-06-29 23:13:26,095, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-06-29 23:13:27,068, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-06-29 23:13:27,068, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-06-29 23:13:27,068, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:27,068, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:27,423, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-06-29 23:13:27,423, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-06-29 23:13:28,445, data_manager.py, 73, INFO, Processing ticker AES
# 2024-06-29 23:13:28,445, data_manager.py, 73, INFO, Processing ticker AES
# 2024-06-29 23:13:28,449, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:28,449, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:28,694, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-29 23:13:28,694, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-29 23:13:29,866, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-29 23:13:29,866, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-29 23:13:29,866, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:29,866, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:30,183, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-29 23:13:30,183, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-29 23:13:31,166, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-29 23:13:31,166, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-29 23:13:31,166, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:31,166, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:31,600, data_manager.py, 82, INFO, Saving data for A by year
# 2024-06-29 23:13:31,600, data_manager.py, 82, INFO, Saving data for A by year
# 2024-06-29 23:13:33,279, data_manager.py, 73, INFO, Processing ticker APD
# 2024-06-29 23:13:33,279, data_manager.py, 73, INFO, Processing ticker APD
# 2024-06-29 23:13:33,286, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:33,286, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:33,905, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-06-29 23:13:33,905, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-06-29 23:13:36,758, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-06-29 23:13:36,758, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-06-29 23:13:36,761, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:36,761, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:36,885, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-29 23:13:36,885, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-29 23:13:37,304, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-29 23:13:37,304, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-29 23:13:37,304, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:37,304, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:37,667, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-29 23:13:37,667, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-29 23:13:39,171, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-29 23:13:39,171, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-29 23:13:39,173, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:39,173, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:39,550, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-29 23:13:39,550, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-29 23:13:40,560, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-29 23:13:40,560, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-29 23:13:40,563, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:40,563, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:40,833, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-06-29 23:13:40,833, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-06-29 23:13:41,894, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-06-29 23:13:41,894, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-06-29 23:13:41,894, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:41,894, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:42,200, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-06-29 23:13:42,200, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-06-29 23:13:43,447, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-06-29 23:13:43,447, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-06-29 23:13:43,450, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:43,450, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:43,718, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-06-29 23:13:43,718, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-06-29 23:13:44,350, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-06-29 23:13:44,350, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-06-29 23:13:44,350, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:44,350, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:44,966, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-06-29 23:13:44,966, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-06-29 23:13:46,016, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-06-29 23:13:46,016, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-06-29 23:13:46,016, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:46,016, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:46,483, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-06-29 23:13:46,483, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-06-29 23:13:47,487, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-06-29 23:13:47,487, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-06-29 23:13:47,487, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:47,487, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:47,799, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-06-29 23:13:47,799, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-06-29 23:13:48,932, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-06-29 23:13:48,932, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-06-29 23:13:48,938, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:48,938, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:49,319, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-06-29 23:13:49,319, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-06-29 23:13:50,664, data_manager.py, 73, INFO, Processing ticker MO
# 2024-06-29 23:13:50,664, data_manager.py, 73, INFO, Processing ticker MO
# 2024-06-29 23:13:50,667, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:50,667, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:51,220, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-06-29 23:13:51,220, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-06-29 23:13:53,133, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-06-29 23:13:53,133, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-06-29 23:13:53,138, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:53,138, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:53,686, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-06-29 23:13:53,686, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-06-29 23:13:55,233, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-06-29 23:13:55,233, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-06-29 23:13:55,249, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:55,249, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:55,550, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-06-29 23:13:55,550, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-06-29 23:13:56,266, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-06-29 23:13:56,266, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-06-29 23:13:56,266, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:56,266, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:56,700, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-06-29 23:13:56,700, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-06-29 23:13:58,558, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-06-29 23:13:58,558, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-06-29 23:13:58,560, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:58,560, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:13:58,802, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-06-29 23:13:58,802, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-06-29 23:13:59,758, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-06-29 23:13:59,758, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-06-29 23:13:59,760, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-06-29
# 2024-06-29 23:13:59,760, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:00,087, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-06-29 23:14:00,087, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-06-29 23:14:01,687, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-06-29 23:14:01,687, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-06-29 23:14:01,690, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:01,690, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:02,204, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-06-29 23:14:02,204, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-06-29 23:14:03,483, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-06-29 23:14:03,483, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-06-29 23:14:03,490, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:03,490, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:03,766, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-06-29 23:14:03,766, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-06-29 23:14:05,167, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-06-29 23:14:05,167, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-06-29 23:14:05,171, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:05,171, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:05,583, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-06-29 23:14:05,583, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-06-29 23:14:07,067, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-06-29 23:14:07,067, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-06-29 23:14:07,067, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:07,067, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:07,485, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-06-29 23:14:07,485, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-06-29 23:14:08,617, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-06-29 23:14:08,617, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-06-29 23:14:08,621, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:08,621, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:08,986, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-06-29 23:14:08,986, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-06-29 23:14:10,289, data_manager.py, 73, INFO, Processing ticker AME
# 2024-06-29 23:14:10,289, data_manager.py, 73, INFO, Processing ticker AME
# 2024-06-29 23:14:10,289, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:10,289, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:10,801, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-06-29 23:14:10,801, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-06-29 23:14:12,684, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-06-29 23:14:12,684, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-06-29 23:14:12,684, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:12,684, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:13,084, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-06-29 23:14:13,084, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-06-29 23:14:14,718, data_manager.py, 73, INFO, Processing ticker APH
# 2024-06-29 23:14:14,718, data_manager.py, 73, INFO, Processing ticker APH
# 2024-06-29 23:14:14,718, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:14,718, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:15,253, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-06-29 23:14:15,253, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-06-29 23:14:16,654, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-06-29 23:14:16,654, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-06-29 23:14:16,662, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:16,662, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:17,136, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-06-29 23:14:17,136, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-06-29 23:14:18,318, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-06-29 23:14:18,318, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-06-29 23:14:18,318, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:18,318, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:18,703, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-06-29 23:14:18,703, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-06-29 23:14:20,032, data_manager.py, 73, INFO, Processing ticker AON
# 2024-06-29 23:14:20,032, data_manager.py, 73, INFO, Processing ticker AON
# 2024-06-29 23:14:20,036, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:20,036, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:20,568, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-06-29 23:14:20,568, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-06-29 23:14:22,017, data_manager.py, 73, INFO, Processing ticker APA
# 2024-06-29 23:14:22,017, data_manager.py, 73, INFO, Processing ticker APA
# 2024-06-29 23:14:22,017, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:22,017, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:22,438, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-06-29 23:14:22,438, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-06-29 23:14:23,773, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-06-29 23:14:23,773, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-06-29 23:14:23,773, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:23,773, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:24,186, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-06-29 23:14:24,186, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-06-29 23:14:25,619, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-06-29 23:14:25,619, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-06-29 23:14:25,619, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:25,619, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:26,102, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-06-29 23:14:26,102, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-06-29 23:14:27,333, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-06-29 23:14:27,333, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-06-29 23:14:27,333, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:27,333, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:27,719, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-06-29 23:14:27,719, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-06-29 23:14:28,452, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-06-29 23:14:28,452, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-06-29 23:14:28,455, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:28,455, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:28,916, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-06-29 23:14:28,916, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-06-29 23:14:30,205, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-06-29 23:14:30,205, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-06-29 23:14:30,207, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:30,207, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:30,533, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-06-29 23:14:30,533, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-06-29 23:14:31,610, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-06-29 23:14:31,610, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-06-29 23:14:31,613, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:31,613, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:31,765, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-06-29 23:14:31,765, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-06-29 23:14:32,148, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-06-29 23:14:32,148, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-06-29 23:14:32,150, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:32,150, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:32,571, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-06-29 23:14:32,571, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-06-29 23:14:34,719, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-06-29 23:14:34,719, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-06-29 23:14:34,719, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:34,719, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:35,119, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-06-29 23:14:35,119, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-06-29 23:14:36,651, data_manager.py, 73, INFO, Processing ticker T
# 2024-06-29 23:14:36,651, data_manager.py, 73, INFO, Processing ticker T
# 2024-06-29 23:14:36,655, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:36,655, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:37,015, data_manager.py, 82, INFO, Saving data for T by year
# 2024-06-29 23:14:37,015, data_manager.py, 82, INFO, Saving data for T by year
# 2024-06-29 23:14:38,621, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-06-29 23:14:38,621, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-06-29 23:14:38,621, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:38,621, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:39,201, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-06-29 23:14:39,201, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-06-29 23:14:40,587, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-06-29 23:14:40,587, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-06-29 23:14:40,587, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:40,587, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:40,869, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-06-29 23:14:40,869, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-06-29 23:14:42,274, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-06-29 23:14:42,274, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-06-29 23:14:42,274, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:42,274, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:42,935, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-06-29 23:14:42,935, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-06-29 23:14:44,185, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-06-29 23:14:44,185, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-06-29 23:14:44,200, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:44,200, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:44,467, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-06-29 23:14:44,467, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-06-29 23:14:46,178, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-06-29 23:14:46,178, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-06-29 23:14:46,187, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:46,187, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:46,674, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-06-29 23:14:46,674, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-06-29 23:14:48,988, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-06-29 23:14:48,988, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-06-29 23:14:48,993, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:48,993, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:49,467, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-06-29 23:14:49,467, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-06-29 23:14:51,166, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-06-29 23:14:51,166, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-06-29 23:14:51,166, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:51,166, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:51,538, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-06-29 23:14:51,538, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-06-29 23:14:52,873, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-06-29 23:14:52,873, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-06-29 23:14:52,873, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:52,873, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:53,300, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-06-29 23:14:53,300, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-06-29 23:14:54,471, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-06-29 23:14:54,471, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-06-29 23:14:54,471, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:54,471, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:54,883, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-06-29 23:14:54,883, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-06-29 23:14:56,124, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-06-29 23:14:56,124, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-06-29 23:14:56,125, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:56,125, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:56,435, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-06-29 23:14:56,435, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-06-29 23:14:58,212, data_manager.py, 73, INFO, Processing ticker BK
# 2024-06-29 23:14:58,212, data_manager.py, 73, INFO, Processing ticker BK
# 2024-06-29 23:14:58,213, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:58,213, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:14:58,550, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-06-29 23:14:58,550, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-06-29 23:14:59,750, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-06-29 23:14:59,750, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-06-29 23:14:59,750, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-06-29
# 2024-06-29 23:14:59,750, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:00,234, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-06-29 23:15:00,234, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-06-29 23:15:01,528, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-06-29 23:15:01,528, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-06-29 23:15:01,530, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:01,530, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:01,851, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-06-29 23:15:01,851, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-06-29 23:15:03,269, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-06-29 23:15:03,269, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-06-29 23:15:03,269, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:03,269, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:03,619, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-06-29 23:15:03,619, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-06-29 23:15:05,281, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-06-29 23:15:05,281, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-06-29 23:15:05,286, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:05,286, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2024-06-29 23:15:06,592, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-06-29 23:15:06,592, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-06-29 23:15:06,594, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-06-29 23:15:06,594, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-06-29 23:15:06,596, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-06-29 23:15:06,596, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-06-29 23:15:06,598, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:06,598, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:07,020, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-06-29 23:15:07,020, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-06-29 23:15:08,634, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-06-29 23:15:08,634, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-06-29 23:15:08,638, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:08,638, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:09,036, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-06-29 23:15:09,036, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-06-29 23:15:10,321, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-06-29 23:15:10,321, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-06-29 23:15:10,324, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:10,324, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:10,583, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-06-29 23:15:10,583, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-06-29 23:15:11,654, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-06-29 23:15:11,654, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-06-29 23:15:11,661, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:11,661, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:11,917, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-06-29 23:15:11,917, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-06-29 23:15:13,116, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-06-29 23:15:13,116, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-06-29 23:15:13,116, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:13,116, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:13,534, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-06-29 23:15:13,534, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-06-29 23:15:14,634, data_manager.py, 73, INFO, Processing ticker BX
# 2024-06-29 23:15:14,634, data_manager.py, 73, INFO, Processing ticker BX
# 2024-06-29 23:15:14,634, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:14,634, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:14,867, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-06-29 23:15:14,867, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-06-29 23:15:15,989, data_manager.py, 73, INFO, Processing ticker BA
# 2024-06-29 23:15:15,989, data_manager.py, 73, INFO, Processing ticker BA
# 2024-06-29 23:15:15,995, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:15,995, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:16,474, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-06-29 23:15:16,474, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-06-29 23:15:17,986, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-06-29 23:15:17,986, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-06-29 23:15:17,986, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:17,986, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:18,318, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-06-29 23:15:18,318, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-06-29 23:15:19,955, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-06-29 23:15:19,955, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-06-29 23:15:19,955, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:19,955, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:20,433, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-06-29 23:15:20,433, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-06-29 23:15:21,567, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-06-29 23:15:21,567, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-06-29 23:15:21,567, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:21,567, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:22,016, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-06-29 23:15:22,016, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-06-29 23:15:23,140, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-06-29 23:15:23,140, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-06-29 23:15:23,142, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:23,142, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:23,451, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-06-29 23:15:23,451, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-06-29 23:15:24,595, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-06-29 23:15:24,595, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-06-29 23:15:24,597, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:24,597, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:25,321, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-06-29 23:15:25,321, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-06-29 23:15:26,750, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-06-29 23:15:26,750, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-06-29 23:15:26,750, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:26,750, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:27,105, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-06-29 23:15:27,105, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-06-29 23:15:28,031, data_manager.py, 73, INFO, Processing ticker BR
# 2024-06-29 23:15:28,031, data_manager.py, 73, INFO, Processing ticker BR
# 2024-06-29 23:15:28,034, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-06-29
# 2024-06-29 23:15:28,034, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:15:28,390, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-06-29 23:15:28,390, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-06-29 23:15:29,690, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-06-29 23:15:29,690, data_manager.py, 73, INFO, Processing ticker BRO
# ...
# 2024-06-29 23:27:48,054, data_manager.py, 82, INFO, Saving data for WRB by year
# 2024-06-29 23:27:49,408, data_manager.py, 73, INFO, Processing ticker WAB
# 2024-06-29 23:27:49,408, data_manager.py, 73, INFO, Processing ticker WAB
# 2024-06-29 23:27:49,409, data_manager.py, 108, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-06-29
# 2024-06-29 23:27:49,409, data_manager.py, 108, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:27:49,721, data_manager.py, 82, INFO, Saving data for WAB by year
# 2024-06-29 23:27:49,721, data_manager.py, 82, INFO, Saving data for WAB by year
# 2024-06-29 23:27:51,121, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-06-29 23:27:51,121, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-06-29 23:27:51,125, data_manager.py, 108, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-06-29
# 2024-06-29 23:27:51,125, data_manager.py, 108, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:27:51,419, data_manager.py, 82, INFO, Saving data for WBA by year
# 2024-06-29 23:27:51,419, data_manager.py, 82, INFO, Saving data for WBA by year
# 2024-06-29 23:27:52,687, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-06-29 23:27:52,687, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-06-29 23:27:52,689, data_manager.py, 108, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-06-29
# 2024-06-29 23:27:52,689, data_manager.py, 108, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:27:53,039, data_manager.py, 82, INFO, Saving data for WMT by year
# 2024-06-29 23:27:53,039, data_manager.py, 82, INFO, Saving data for WMT by year
# 2024-06-29 23:27:54,665, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-06-29 23:27:54,665, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-06-29 23:27:54,669, data_manager.py, 108, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-06-29
# 2024-06-29 23:27:54,669, data_manager.py, 108, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:27:54,986, data_manager.py, 82, INFO, Saving data for DIS by year
# 2024-06-29 23:27:54,986, data_manager.py, 82, INFO, Saving data for DIS by year
# 2024-06-29 23:27:56,306, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-06-29 23:27:56,306, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-06-29 23:27:56,308, data_manager.py, 108, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-06-29
# 2024-06-29 23:27:56,308, data_manager.py, 108, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:27:56,524, data_manager.py, 82, INFO, Saving data for WBD by year
# 2024-06-29 23:27:56,524, data_manager.py, 82, INFO, Saving data for WBD by year
# 2024-06-29 23:27:57,757, data_manager.py, 73, INFO, Processing ticker WM
# 2024-06-29 23:27:57,757, data_manager.py, 73, INFO, Processing ticker WM
# 2024-06-29 23:27:57,759, data_manager.py, 108, INFO, Getting stock price data for WM from 2000-01-01 to 2024-06-29
# 2024-06-29 23:27:57,759, data_manager.py, 108, INFO, Getting stock price data for WM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:27:58,211, data_manager.py, 82, INFO, Saving data for WM by year
# 2024-06-29 23:27:58,211, data_manager.py, 82, INFO, Saving data for WM by year
# 2024-06-29 23:27:59,724, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-06-29 23:27:59,724, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-06-29 23:27:59,726, data_manager.py, 108, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-06-29
# 2024-06-29 23:27:59,726, data_manager.py, 108, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:27:59,985, data_manager.py, 82, INFO, Saving data for WAT by year
# 2024-06-29 23:27:59,985, data_manager.py, 82, INFO, Saving data for WAT by year
# 2024-06-29 23:28:01,331, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-06-29 23:28:01,331, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-06-29 23:28:01,333, data_manager.py, 108, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:01,333, data_manager.py, 108, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:01,746, data_manager.py, 82, INFO, Saving data for WEC by year
# 2024-06-29 23:28:01,746, data_manager.py, 82, INFO, Saving data for WEC by year
# 2024-06-29 23:28:03,714, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-06-29 23:28:03,714, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-06-29 23:28:03,718, data_manager.py, 108, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:03,718, data_manager.py, 108, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:04,107, data_manager.py, 82, INFO, Saving data for WFC by year
# 2024-06-29 23:28:04,107, data_manager.py, 82, INFO, Saving data for WFC by year
# 2024-06-29 23:28:05,577, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-06-29 23:28:05,577, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-06-29 23:28:05,578, data_manager.py, 108, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:05,578, data_manager.py, 108, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:05,844, data_manager.py, 82, INFO, Saving data for WELL by year
# 2024-06-29 23:28:05,844, data_manager.py, 82, INFO, Saving data for WELL by year
# 2024-06-29 23:28:07,130, data_manager.py, 73, INFO, Processing ticker WST
# 2024-06-29 23:28:07,130, data_manager.py, 73, INFO, Processing ticker WST
# 2024-06-29 23:28:07,133, data_manager.py, 108, INFO, Getting stock price data for WST from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:07,133, data_manager.py, 108, INFO, Getting stock price data for WST from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:07,689, data_manager.py, 82, INFO, Saving data for WST by year
# 2024-06-29 23:28:07,689, data_manager.py, 82, INFO, Saving data for WST by year
# 2024-06-29 23:28:09,020, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-06-29 23:28:09,020, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-06-29 23:28:09,021, data_manager.py, 108, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:09,021, data_manager.py, 108, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:09,339, data_manager.py, 82, INFO, Saving data for WDC by year
# 2024-06-29 23:28:09,339, data_manager.py, 82, INFO, Saving data for WDC by year
# 2024-06-29 23:28:10,968, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-06-29 23:28:10,968, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-06-29 23:28:10,973, data_manager.py, 108, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:10,973, data_manager.py, 108, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:11,389, data_manager.py, 82, INFO, Saving data for WRK by year
# 2024-06-29 23:28:11,389, data_manager.py, 82, INFO, Saving data for WRK by year
# 2024-06-29 23:28:12,241, data_manager.py, 73, INFO, Processing ticker WY
# 2024-06-29 23:28:12,241, data_manager.py, 73, INFO, Processing ticker WY
# 2024-06-29 23:28:12,243, data_manager.py, 108, INFO, Getting stock price data for WY from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:12,243, data_manager.py, 108, INFO, Getting stock price data for WY from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:12,613, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-06-29 23:28:12,613, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-06-29 23:28:14,329, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-06-29 23:28:14,329, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-06-29 23:28:14,331, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:14,331, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:14,701, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-06-29 23:28:14,701, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-06-29 23:28:16,376, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-06-29 23:28:16,376, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-06-29 23:28:16,379, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:16,379, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:16,817, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-06-29 23:28:16,817, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-06-29 23:28:18,708, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-06-29 23:28:18,708, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-06-29 23:28:18,712, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:18,712, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:19,163, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-06-29 23:28:19,163, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-06-29 23:28:20,576, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-06-29 23:28:20,576, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-06-29 23:28:20,578, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:20,578, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:20,857, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-06-29 23:28:20,857, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-06-29 23:28:22,281, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-06-29 23:28:22,281, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-06-29 23:28:22,285, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:22,285, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:22,657, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-06-29 23:28:22,657, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-06-29 23:28:23,947, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-06-29 23:28:23,947, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-06-29 23:28:23,949, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:23,949, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:24,624, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-06-29 23:28:24,624, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-06-29 23:28:26,498, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-06-29 23:28:26,498, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-06-29 23:28:26,502, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:26,502, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:26,855, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-06-29 23:28:26,855, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-06-29 23:28:27,981, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-06-29 23:28:27,981, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-06-29 23:28:27,985, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:27,985, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:28,544, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-29 23:28:28,544, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-29 23:28:30,105, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-29 23:28:30,105, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-29 23:28:30,106, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:30,106, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:30,475, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-06-29 23:28:30,475, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-06-29 23:28:32,241, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-06-29 23:28:32,241, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-06-29 23:28:32,244, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:32,244, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:32,570, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-06-29 23:28:32,570, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-06-29 23:28:33,990, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-06-29 23:28:33,990, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-06-29 23:28:33,990, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:33,990, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:34,378, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-29 23:28:34,378, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-29 23:28:35,689, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-29 23:28:35,689, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-29 23:28:35,692, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-29
# 2024-06-29 23:28:35,692, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 23:28:35,875, data_manager.py, 82, INFO, Saving data for ZTS by year
# 2024-06-29 23:28:35,875, data_manager.py, 82, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-06-29 23:28:36,474, data_manager.py, 117, INFO, Creating features data.
# 2024-06-29 23:28:36,474, data_manager.py, 117, INFO, Creating features data.
# 2024-06-29 23:28:36,478, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# 2024-06-29 23:28:36,478, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-06-29 23:28:39,555, data_manager.py, 136, INFO, Creating features
# 2024-06-29 23:28:39,555, data_manager.py, 136, INFO, Creating features
# c:\Users\nares\OneDrive\Desktop\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:138: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-06-29 23:28:39,838, data_manager.py, 154, INFO, Creating target
# 2024-06-29 23:28:39,838, data_manager.py, 154, INFO, Creating target
# c:\Users\nares\OneDrive\Desktop\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:155: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-06-29 23:28:39,976, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-06-29 23:28:39,976, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 dm.featurize()
#
# File c:\Users\nares\OneDrive\Desktop\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:121, in DataManager.featurize(self)
#     119 self.create_features()
#     120 self.create_target()
# --> 121 self.save_features()
#
# File c:\Users\nares\OneDrive\Desktop\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:168, in DataManager.save_features(self)
#     164 _logs.info(f'Saving features to {self.features_path}')
#     165 feat_out = (self
#     166  .features
#     167  .repartition(npartitions = 500))
# --> 168 feat_out.to_parquet(
#     169     self.features_path,
#     170     write_index = True,
#     171     overwrite = True)
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5849, in DataFrame.to_parquet(self, path, *args, **kwargs)
#    5846 """See dd.to_parquet docstring for more information"""
#    5847 from dask.dataframe.io import to_parquet
# -> 5849 return to_parquet(self, path, *args, **kwargs)
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:1047, in to_parquet(df, path, engine, compression, write_index, append, overwrite, ignore_divisions, partition_on, storage_options, custom_metadata, write_metadata_file, compute, compute_kwargs, schema, name_function, filesystem, **kwargs)
#    1044 out = Scalar(graph, final_name, "")
#    1046 if compute:
# -> 1047     out = out.compute(**compute_kwargs)
#    1049 # Invalidate the filesystem listing cache for the output path after write.
#    1050 # We do this before returning, even if `compute=False`. This helps ensure
#    1051 # that reading files that were just written succeeds.
#    1052 fs.invalidate_cache(path)
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:377, in DaskMethodsMixin.compute(self, **kwargs)
#     353 def compute(self, **kwargs):
#     354     """Compute this dask collection
#     355
#     356     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     375     dask.compute
#     376     """
# --> 377     (result,) = compute(self, traverse=False, **kwargs)
#     378     return result
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:663, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     660     postcomputes.append(x.__dask_postcompute__())
#     662 with shorten_traceback():
# --> 663     results = schedule(dsk, keys, **kwargs)
#     665 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:97, in ParquetFunctionWrapper.__call__(self, part)
#      94 if not isinstance(part, list):
#      95     part = [part]
# ---> 97 return read_parquet_part(
#      98     self.fs,
#      99     self.engine,
#     100     self.meta,
#     101     [
#     102         # Temporary workaround for HLG serialization bug
#     103         # (see: https://github.com/dask/dask/issues/8581)
#     104         (p.data["piece"], p.data.get("kwargs", {}))
#     105         if hasattr(p, "data")
#     106         else (p["piece"], p.get("kwargs", {}))
#     107         for p in part
#     108     ],
#     109     self.columns,
#     110     self.index,
#     111     self.common_kwargs,
#     112 )
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:645, in read_parquet_part(fs, engine, meta, part, columns, index, kwargs)
#     642 if len(part) == 1 or part[0][1] or not check_multi_support(engine):
#     643     # Part kwargs expected
#     644     func = engine.read_partition
# --> 645     dfs = [
#     646         func(
#     647             fs,
#     648             rg,
#     649             columns.copy(),
#     650             index,
#     651             **toolz.merge(kwargs, kw),
#     652         )
#     653         for (rg, kw) in part
#     654     ]
#     655     df = concat(dfs, axis=0) if len(dfs) > 1 else dfs[0]
#     656 else:
#     657     # No part specific kwargs, let engine read
#     658     # list of parts at once
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:646, in <listcomp>(.0)
#     642 if len(part) == 1 or part[0][1] or not check_multi_support(engine):
#     643     # Part kwargs expected
#     644     func = engine.read_partition
#     645     dfs = [
# --> 646         func(
#     647             fs,
#     648             rg,
#     649             columns.copy(),
#     650             index,
#     651             **toolz.merge(kwargs, kw),
#     652         )
#     653         for (rg, kw) in part
#     654     ]
#     655     df = concat(dfs, axis=0) if len(dfs) > 1 else dfs[0]
#     656 else:
#     657     # No part specific kwargs, let engine read
#     658     # list of parts at once
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:640, in ArrowDatasetEngine.read_partition(cls, fs, pieces, columns, index, dtype_backend, categories, partitions, filters, schema, **kwargs)
#     637     row_group = [row_group]
#     639 # Read in arrow table and convert to pandas
# --> 640 arrow_table = cls._read_table(
#     641     path_or_frag,
#     642     fs,
#     643     row_group,
#     644     columns,
#     645     schema,
#     646     filters,
#     647     partitions,
#     648     partition_keys,
#     649     **kwargs,
#     650 )
#     651 if multi_read:
#     652     tables.append(arrow_table)
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:1773, in ArrowDatasetEngine._read_table(cls, path_or_frag, fs, row_groups, columns, schema, filters, partitions, partition_keys, **kwargs)
#    1766     arrow_table = frag.to_table(
#    1767         use_threads=False,
#    1768         schema=schema,
#    1769         columns=cols,
#    1770         filter=_filters_to_expression(filters) if filters else None,
#    1771     )
#    1772 else:
# -> 1773     arrow_table = _read_table_from_path(
#    1774         path_or_frag,
#    1775         fs,
#    1776         row_groups,
#    1777         columns,
#    1778         schema,
#    1779         filters,
#    1780         **kwargs,
#    1781     )
#    1783 # For pyarrow.dataset api, if we did not read directly from
#    1784 # fragments, we need to add the partitioned columns here.
#    1785 if partitions and isinstance(partitions, list):
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:256, in _read_table_from_path(path, fs, row_groups, columns, schema, filters, **kwargs)
#     253 pre_buffer_default = precache_options.get("method", None) is None
#     254 pre_buffer = {"pre_buffer": read_kwargs.pop("pre_buffer", pre_buffer_default)}
# --> 256 with _open_input_files(
#     257     [path],
#     258     fs=fs,
#     259     precache_options=precache_options,
#     260     **open_file_options,
#     261 )[0] as fil:
#     262     if row_groups == [None]:
#     263         return pq.ParquetFile(fil, **pre_buffer).read(
#     264             columns=columns,
#     265             use_threads=False,
#     266             use_pandas_metadata=True,
#     267             **read_kwargs,
#     268         )
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\utils.py:221, in _open_input_files(paths, fs, context_stack, open_file_func, precache_options, **kwargs)
#     208     return [
#     209         _set_context(
#     210             fsspec_parquet.open_parquet_file(
#    (...)
#     218         for path, rgs in zip(paths, row_groups)
#     219     ]
#     220 elif fs is not None:
# --> 221     return [_set_context(fs.open(path, **kwargs), context_stack) for path in paths]
#     222 return [_set_context(open(path, **kwargs), context_stack) for path in paths]
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\utils.py:221, in <listcomp>(.0)
#     208     return [
#     209         _set_context(
#     210             fsspec_parquet.open_parquet_file(
#    (...)
#     218         for path, rgs in zip(paths, row_groups)
#     219     ]
#     220 elif fs is not None:
# --> 221     return [_set_context(fs.open(path, **kwargs), context_stack) for path in paths]
#     222 return [_set_context(open(path, **kwargs), context_stack) for path in paths]
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\spec.py:1307, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1305 else:
#    1306     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1307     f = self._open(
#    1308         path,
#    1309         mode=mode,
#    1310         block_size=block_size,
#    1311         autocommit=ac,
#    1312         cache_options=cache_options,
#    1313         **kwargs,
#    1314     )
#    1315     if compression is not None:
#    1316         from fsspec.compression import compr
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\implementations\local.py:180, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     178 if self.auto_mkdir and "w" in mode:
#     179     self.makedirs(self._parent(path), exist_ok=True)
# --> 180 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\implementations\local.py:302, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     300 self.compression = get_compression(path, compression)
#     301 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 302 self._open()
#
# File c:\Users\nares\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\implementations\local.py:307, in LocalFileOpener._open(self)
#     305 if self.f is None or self.f.closed:
#     306     if self.autocommit or "w" not in self.mode:
# --> 307         self.f = open(self.path, mode=self.mode)
#     308         if self.compression:
#     309             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/Users/nares/OneDrive/Desktop/scaling_to_production/05_src/data/prices/TSLA/TSLA_2019.parquet/part.0.parquet'
